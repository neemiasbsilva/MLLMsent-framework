# %%
import pandas as pd
import json

# %%
f = open("../data/raw/senticap_dataset/data/senticap_dataset.json")
 
data = json.load(f)

f.close()

# %%
def preprocess_sentcap(data):

# %%
print(f'Number of samples: {len(data["images"])}')

# %%
data["images"][0].keys()

# %%
len(data["images"][0]["sentences"])

# %%
data["images"][1]["sentences"][2]

# %%
"I make great coffee. It is the best coffee because of my secret blend."
"A clean sleek kitchen the sun streaming in through the tall window."
"A beautiful well-appointed kitchen with a counter window."
